# %%
import pandas as pd #加载模块

#读取csv
data = pd.read_csv('~/ghome/github/Numpy-Pandas/numpy-learning/student.csv')

#打印出data
print(data)
# Out:
#     Student ID  name   age  gender
# 0         1100  Kelly   22  Female
# 1         1101    Clo   21  Female
# 2         1102  Tilly   22  Female
# 3         1103   Tony   24    Male
# 4         1104  David   20    Male
# 5         1105  Catty   22  Female
# 6         1106      M    3  Female
# 7         1107      N   43    Male
# 8         1108      A   13    Male
# 9         1109      S   12    Male
# 10        1110  David   33    Male
# 11        1111     Dw    3  Female
# 12        1112      Q   23    Male
# 13        1113      W   21  Female

# %%
data.to_pickle('student.pickle')
